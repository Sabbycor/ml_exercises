# %% [markdown]
# # Matrice di correlazione

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [[80, 1995, 16], [150, 1995, 30], [30, 2008, 12], [50, 1996, 10], 
            [120, 1994, 24], [60, 2006, 18], [110, 1989, 20], [110, 2000, 25]]

df = pd.DataFrame(data, columns=["Dimensione", "Anno di costruzione", "Valore"])
df
# Out:
#    Dimensione  Anno di costruzione  Valore
# 0          80                 1995      16
# 1         150                 1995      30
# 2          30                 2008      12
# 3          50                 1996      10
# 4         120                 1994      24
# 5          60                 2006      18
# 6         110                 1989      20
# 7         110                 2000      25

# %%
# Costruiamo una heatmap

plt.figure(figsize=(14,10), dpi=80)

hm = sns.heatmap(df.corr(),
                 cbar=True,
                 square=True,
                 yticklabels=df.columns,
                 xticklabels=df.columns,
                 annot=True,                  # Questo ci mostra i valori degli indici
                 annot_kws={'size':18})       # Impostiamo la dimensione dell'annotazione a 12 per farla entrare dentro il quadrato

plt.show()
